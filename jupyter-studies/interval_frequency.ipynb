# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import math

# %%
df = pd.read_csv('/Users/victoroliveira/Desktop/vonix-py-statistic/src/vonixstatisc/data/pandas_data/data_fluency_queue.csv')

# %%
df
# Out:
#         agent_id        queue_id direction  locality_id  call_type_id  \
# 0           1000        equipez4       OUT      66000.0             3
# 1           1000        equipez4      AUTO         91.0             5
# 2           1000        equipez4      AUTO         89.0             5
# 3           1000        equipez4      AUTO         48.0             4
# 4           1000        equipez4      AUTO         31.0             5
# ...          ...             ...       ...          ...           ...
# 117583      1573  isnrecuperacao       OUT         11.0             5
# 117584      1137       isjaguars       OUT         21.0             5
# 117585      1572        isnxsell       OUT         11.0             5
# 117586      1600        mgmsales       OUT         89.0             5
# 117587      1572        isnxsell       OUT         11.0             5
#
#         hold_secs  ring_secs  initial_position  trunking_id  carrier_id  \
# ...

# %%
df_march = df.loc[df['month'] == 'March']

# %%
df_march.pop('month')
# Out:
# 9337     March
# 9338     March
# 9339     March
# 9340     March
# 9341     March
#          ...
# 76070    March
# 76071    March
# 76072    March
# 76073    March
# 76074    March
# Name: month, Length: 66738, dtype: object

# %%
df_march
# Out:
#        agent_id   queue_id direction  locality_id  call_type_id  hold_secs  \
# 9337       1124   equipez4       OUT         11.0             5          0
# 9338       1124   equipez6      AUTO         94.0             5          1
# 9339       1120   equipez6      AUTO          NaN             5          1
# 9340       1140   equipez6      AUTO         17.0             5          2
# 9341       1124   equipez6      AUTO         19.0             5          2
# ...         ...        ...       ...          ...           ...        ...
# 76070      1128    isfoxes       OUT         11.0             5          0
# 76071      1533  isjaguars       OUT         24.0             5          0
# 76072      1116  isjaguars       OUT         21.0             5          0
# 76073      1572  isdragons       OUT         13.0             5          0
# 76074      1554   iswolves       OUT         11.0             5          0
#
# ...

# %%
sns.set_theme(style="whitegrid")
sns.stripplot(df, x="week_day", y="handling_time", hue="agent_id", jitter=True)
plt.show()

# %%
df_february_1650 = df.loc[df['agent_id'] == 1650]
df_february_1650
# Out:
#         agent_id  queue_id direction  locality_id  call_type_id  hold_secs  \
# 93982       1650  equipez4      AUTO          NaN             5          2
# 94010       1650  equipez4      AUTO         11.0             5          2
# 94237       1650  equipez4      AUTO         19.0             5          1
# 94272       1650  equipez4      AUTO         37.0             5          2
# 94274       1650  equipez4      AUTO         62.0             5          8
# ...          ...       ...       ...          ...           ...        ...
# 115649      1650  equipez6      AUTO         27.0             5          2
# 115659      1650  equipez6      AUTO         75.0             5          2
# 115670      1650  equipez6      AUTO         66.0             5          1
# 115680      1650  equipez6      AUTO         41.0             8          2
# 115706      1650  equipez6      AUTO         37.0             5          2
#
# ...

# %%
sns.set_theme(style="whitegrid")
sns.stripplot(df_february_1650, x="week_day", y="handling_time", hue = 'hour', jitter=True)
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.lineplot(df_february_1650, x="timestamp", y="handling_time")
plt.show()

# %%
df_february_1000 = df.loc[df['agent_id'] == 1000]
df_february_1000
# Out:
#        agent_id   queue_id direction  locality_id  call_type_id  hold_secs  \
# 0          1000   equipez4       OUT      66000.0             3          0
# 1          1000   equipez4      AUTO         91.0             5          1
# 2          1000   equipez4      AUTO         89.0             5          1
# 3          1000   equipez4      AUTO         48.0             4         14
# 4          1000   equipez4      AUTO         31.0             5          2
# 23844      1000  ishunters       OUT         69.0             5          0
# 24227      1000  ishunters       OUT         81.0             5          0
# 29700      1000  ishunters       OUT         98.0             5          0
# 29704      1000  ishunters       OUT         21.0             5          0
# 29707      1000  ishunters       OUT         49.0             4          0
# 29746      1000  ishunters       OUT         99.0             5          0
# ...

# %%
sns.set_theme(style="whitegrid")
sns.lineplot(df_february_1000, x="timestamp", y="handling_time")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot(df_february_1000, x ="handling_time")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot(df_february_1650, x="handling_time", kde = True)
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot(df_february_1000, x="handling_time", kde = True)
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot(df, x="handling_time")
plt.show()

# %%
df_1131 = df.loc[df['agent_id'] == 1131]
df_1131
# Out:
#         agent_id   queue_id direction  locality_id  call_type_id  hold_secs  \
# 28          1131   equipez4      AUTO         31.0             5          1
# 124         1131   equipez4      AUTO         21.0             5          1
# 129         1131   equipez4      AUTO         55.0             5         12
# 147         1131   equipez4      AUTO         31.0             5          2
# 157         1131   equipez4      AUTO         55.0             5          1
# ...          ...        ...       ...          ...           ...        ...
# 117485      1131  isfalcons       OUT         81.0             5          0
# 117491      1131  isfalcons       OUT         61.0             5          0
# 117498      1131  isfalcons       OUT         98.0             5          0
# 117534      1131  isfalcons       OUT         84.0             5          0
# 117542      1131  isfalcons       OUT         11.0             5          0
#
# ...

# %%
def condition(x):
    return math.ceil(x/180)

# %%
df_mean['interval_mean'] = df['handling_time'].apply(condition)

# %%
df
# Out:
#         agent_id        queue_id direction  locality_id  call_type_id  \
# 0           1000        equipez4       OUT      66000.0             3
# 1           1000        equipez4      AUTO         91.0             5
# 2           1000        equipez4      AUTO         89.0             5
# 3           1000        equipez4      AUTO         48.0             4
# 4           1000        equipez4      AUTO         31.0             5
# ...          ...             ...       ...          ...           ...
# 117583      1573  isnrecuperacao       OUT         11.0             5
# 117584      1137       isjaguars       OUT         21.0             5
# 117585      1572        isnxsell       OUT         11.0             5
# 117586      1600        mgmsales       OUT         89.0             5
# 117587      1572        isnxsell       OUT         11.0             5
#
#         hold_secs  ring_secs  initial_position  trunking_id  carrier_id  \
# ...

# %%
sns.set_theme(style="whitegrid")
sns.histplot(df, x="interval", bins = [1,2,3,4,5,6,7,8,9])
plt.show()

# %%
df_march= df.loc[df['month'] == 'March'] 
df_march_1131 = df_march.loc[df['agent_id'] == 1131]
df_march_1131 = df_march_1131.loc[df['handling_time'] > 10]
sns.set_theme(style="whitegrid")
sns.histplot(df_march_1131, x="interval", kde =True)
X = 1.0
plt.xticks(np.arange(1, 15, X))
plt.show()

# %%
df_march_1131 = df_march_1131.loc[df['handling_time'] > 8]

# %%
df_march_1131_frequency =df_march_1131['interval'].value_counts()

# %%
df_march_1131_frequency
# Out:
# 1    305
# 2     14
# 3      6
# 4      3
# 5      2
# 8      1
# 6      1
# 9      1
# Name: interval, dtype: int64

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize = (30,10)) 
sns.lineplot(df_march_1131, x="day", y = "interval")
plt.show()

# %%
df_arr = df_march_1131["handling_time"].to_numpy()

# %%
def transform_array(array: list, interval: list, min_time: list, max_time: list):
    """Used inside StandardModel : loops using transform_dict to create dicts for the standard model
     - receives array [talk_secs from a chosen 15min, 30min 1hr period] ex : [194,30303,21,1,0,3,1231,6547,8869]
     - for standard model, interval = 180 secs, min_time = 8 secs, max_time = 5400 secs
     - filters data between min and max time [194,503,21,1231]
    {180: [21,194], 360 [303], ... interval of three minutes}"""

    limit = interval
    arr = []
    beginning = 0
    return_dict = {}
    end = beginning + interval

    sort_data = [
        time for time in np.sort(array) if time >= min_time and time <= max_time
    ]

    for time in sort_data:
        last_time = sort_data[-1]
        if time <= limit:
            arr.append(time)

        if time > limit:
            if len(arr) > 0:
                return_dict[limit] = arr

            arr = []
            arr.append(time)

            beginning += interval
            end += interval
            limit += interval

        if time == last_time:
            return_dict[limit] = arr

    return return_dict

# %%
df_tr = transform_array(df_arr, interval =  90, min_time = 8, max_time= 5400)

# %%
df_tr
# Out:
# {90: [11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   14,
#   15,
#   15,
#   15,
#   15,
#   15,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   17,
#   17,
#   17,
#   17,
#   18,
#   18,
#   18,
#   18,
#   18,
#   18,
#   18,
#   18,
#   19,
#   19,
#   19,
#   19,
#   20,
#   20,
#   21,
#   21,
#   21,
#   21,
#   21,
#   21,
#   22,
#   22,
#   22,
#   22,
#   22,
#   22,
#   23,
#   23,
#   23,
#   23,
#   24,
#   24,
#   24,
#   25,
#   25,
#   25,
#   25,
#   26,
#   26,
#   26,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   28,
#   28,
#   28,
#   28,
#   28,
#   29,
#   29,
#   29,
#   29,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   31,
#   31,
#   31,
#   31,
#   31,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   33,
#   33,
# ...

# %%
    def construct_model(data) -> dict:
        data = transform_array(data, 90, 8, 5400)
        dict_model = {i: round(np.mean(data[i])) for i in data}
        return dict_model

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 construct_model(df_tr)
#
# Cell In[205], line 2, in construct_model(self)
#       1 def construct_model(self) -> dict:
# ----> 2     data = transform_array(self.__data, 90, 8, 5400)
#       3     dict_model = {i: round(np.mean(data[i])) for i in data}
#       4     return dict_model
#
# AttributeError: 'dict' object has no attribute '__data'
